# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("openaq-exploration")
    .config("spark.sql.shuffle.partitions", "4")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
spark.version
# Out:
# '4.2.0'

# %%
df = spark.read.parquet("../data/output/openaq_location_latest")
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- location_id: long (nullable = true)
#  |-- sensor_id: long (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- parameter_display_name: string (nullable = true)
#  |-- value: double (nullable = true)
#  |-- unit: string (nullable = true)
#  |-- measured_at_utc_raw: string (nullable = true)
#  |-- measured_at_utc: timestamp (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#
# +-----------+---------+---------+----------------------+------+-----+--------------------+-------------------+--------+-----------+
# |location_id|sensor_id|parameter|parameter_display_name|value |unit |measured_at_utc_raw |measured_at_utc    |latitude|longitude  |
# +-----------+---------+---------+----------------------+------+-----+--------------------+-------------------+--------+-----------+
# |2178       |3916     |no2      |NO₂                   |0.007 |ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |3918     |so2      |SO₂                   |4.0E-4|ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |3920     |pm25     |PM2.5                 |4.0   |µg/m³|2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |3917     |o3       |O₃                    |0.037 |ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |3919     |pm10     |PM10                  |14.0  |µg/m³|2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |25227    |co       |CO                    |0.1   |ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |4272103  |nox      |NOx                   |0.008 |ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# |2178       |4272226  |no       |NO                    |6.0E-4|ppm  |2026-08-13T13:00:00Z|2026-08-13 15:00:00|35.1353 |-106.584702|
# +-----------+---------+---------+----------------------+------+-----+--------------------+-------------------+--------+-----------+
